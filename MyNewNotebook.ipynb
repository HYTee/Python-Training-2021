# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#calculate
2*(3+4)
print('first value:',1)
print('second value:',2)

numbers = [4,3,2,1]
numbers.sort()
print(numbers)
# Out:
# first value: 1
# second value: 2
# [1, 2, 3, 4]
